# %%
import gzip
import pickle
from os.path import join, expanduser
import numpy as np
import pandas as pd
import json

# %%
input_path = expanduser('~/data/jstor/latest/')
output_path = expanduser('~/data/jstor/latest/')
prefix = 'ngrams_dict'
dois = ['10.2307/3069368', '10.2307/20159507']

with open(join(output_path, 'registry_json.txt')) as file:
    registry_dict = json.loads(file.read())

# %%
def get_chunk(fpath, prefix, index):
    """
    return chunk number index
    """
    fname = join(fpath, '{0}_{1}.pgz'.format(prefix, index))
    with gzip.open(fname) as fp:
        item = pickle.load(fp)
        return item
    return None

def get_articles(dois, registry_dict, fpath, prefix):
    """
    get articles by dois
    """
    doi_chunk_map = find_doi_chunk_map(dois, registry_dict)
    chunks_to_load = list(set(doi_chunk_map.values()))
    chunks_dict = {ii: get_chunk(fpath, prefix, ii) for ii in chunks_to_load}
    doi_ngram_dict = {doi:chunks_dict[doi_chunk_map[doi]][doi] for doi in dois}
    return doi_ngram_dict

def find_doi_chunk_map(dois, registry_dict):
    return {k : [kk for kk, val in registry_dict.items() if k in val][0] for k in dois}

def load_ngram_dist(fpath, order, thr=2):
    fname = join(fpath, 'corpus_ngram_dist_n_{0}_thr_{1}.pgz'.format(order, thr))
    with gzip.open(fname) as fp:
        distr_dict = pickle.load(fp)
    if order == 1:
        distr_dict = {k[0]: v for k, v in distr_dict.items()}
    return distr_dict

# %%
dch_dict = get_articles(dois, registry_dict, input_path, prefix)

# %%
# dch_dict[dois[0]][3]
ngram_order = 2

# %%
distr_dict = load_ngram_dist(input_path, ngram_order)

# %%
keys = sorted(distr_dict.keys())
# vals = np.array([distr_dict[k] for k in keys])
# df = pd.DataFrame(vals, keys, columns=['f', 'f-', 'f+', 'n']).sort_values('n')
# df.tail(20)

# %%
# a single article
article = dch_dict[dois[0]]
ngram_positions_list = article[ngram_order]
ngram_counts = {k: len(v) for k, v in ngram_positions_list.items()}
ngram_number = sum(ngram_counts.values())
ngram_freqs = {k: v/ngram_number for k, v in ngram_counts.items() if k in distr_dict.keys()}
len(ngram_freqs)
# Out:
# 2669

# %%
ngram_freqs_outstanding = {k: v/distr_dict[k][0] for k, v in ngram_freqs.items()} 
len(ngram_counts), len(ngram_freqs), len(ngram_freqs_outstanding)
# Out:
# (3476, 2669, 2669)

# %%
keys = sorted(ngram_freqs_outstanding.keys())
vals = np.array([(ngram_freqs_outstanding[k], ngram_counts[k], distr_dict[k][-1], 1./distr_dict[k][-1]) 
                 for k in keys])
print(len(keys), vals.shape)
df = pd.DataFrame(vals, keys, columns=['tf_idf', 'n_article', 
                                       'n_corpus', 'inv_n_corpus']).sort_values(['n_article', 'inv_n_corpus'])
df.tail(20)
# Out:
# 2669 (2669, 4)
#                                    tf_idf  n_article  n_corpus  inv_n_corpus
# (finkelstein, hambrick)        113.680340       13.0     558.0      0.001792
# (management, team's)           773.580850       13.0      82.0      0.012195
# (expansiveness, firm's)       4879.509979       13.0      13.0      0.076923
# (demographic, effect)          481.530590       15.0     152.0      0.006579
# (tmt, characteristic)         1045.609281       15.0      70.0      0.014286
# (firm's, global)              2614.023203       15.0      28.0      0.035714
# (firm, tenure)                 523.974226       16.0     149.0      0.006711
# (relationship, top)            772.991680       16.0     101.0      0.009901
# (tmt, demographic)            3318.066786       17.0      25.0      0.040000
# (educational, heterogeneity)  3606.594332       17.0      23.0      0.043478
# (management, journal)            3.043670       18.0   28857.0      0.000035
# (functional, heterogeneity)   1084.335551       18.0      81.0      0.012346
# (environmental, uncertainty)    57.373858       21.0    1786.0      0.000560
# (tenure, heterogeneity)       1297.084931       21.0      79.0      0.012658
# (management, team)              37.674226       27.0    3497.0      0.000286
# (upper, echelon)               247.179680       27.0     533.0      0.001876
# (top, team)                    294.735502       27.0     447.0      0.002237
# (top, management)               32.404468       43.0    6475.0      0.000154
# (strategic, posture)          1262.267060       67.0     259.0      0.003861
# (global, strategic)           1543.286877       68.0     215.0      0.004651

# %%
ngram_order = 1
ngram_positions_list = article[ngram_order]

# %%
ixs = ngram_positions_list['hypothesis']

# %%
fname = expanduser('~/data/jstor/latest/corpus_clean_dict.pgz')
with gzip.open(fname) as fp:
    articles_ds = pickle.load(fp)

# %%
carticle = articles_ds[dois[0]]

# %%
list(range(-1, 2))
# Out:
# [-1, 0, 1]

# %%
for i in ixs:
    js = range(i-1, i + 2)
    for j in js:
        phrase = ' '.join(carticle[j])
        doc = nlp(phrase)
        for chunk in doc.noun_chunks:
            print(chunk.text, '|', chunk.root.text, chunk.root.dep_,
                  chunk.root.head.text)
# Out:
# we | we nsubj hypothesized
# such breadth | breadth nsubjpass related
# diversity | diversity conj breadth
# global strategic posture | posture pobj to
# a positive relationship | relationship attr be
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# a positive relationship | relationship attr be
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# Hypothesis | Hypothesis nsubj lb
# a positive relationship | relationship attr be
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a positive relationship | relationship attr be
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Hypothesis Ic | Ic ROOT Ic
# a positive relationship | relationship attr be
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a positive relationship | relationship attr be
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Hypothesis | Hypothesis dobj d
# I | I nsubj d
# a positive relationship | relationship attr be
# a top management team's firm tenure heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# the complexity | complexity pobj Given
# characterizing firms | firms pobj Given
# expansive global positions | positions pobj with
# hence the need | need conj firms
# both diversity | diversity pobj for
# high levels | levels conj diversity
# teamwork | teamwork pobj of
# their top management teams | teams pobj in
# Kim Mauborgne | Mauborgne appos teams
# Weick Van Orden | Orden conj Mauborgne
# this evidence | evidence nsubj suggests
# the relationship | relationship nsubjpass curvilinear
# TMT characteristics | characteristics pobj between
# global strategic posture | posture conj characteristics
# an inverted U | U dobj curvilinear
# we | we nsubj offer
# the following hypotheses | hypotheses dobj offer
# alternatives | alternatives pobj as
# the linear relationships | relationships pobj to
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's firm tenure heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# reason | reason attr is
# such uncertainty | uncertainty nsubj affect
# the relationship | relationship dobj affect
# TMT demographics | demographics pobj between
# global strategic posture | posture conj demographics
# the context | context pobj In
# this study | study pobj of
# it | it nsubj suggests
# the following hypotheses | hypotheses dobj suggests
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's educational heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's functional heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's firm tenure heterogeneity | heterogeneity pobj between
# the expansiveness | expansiveness conj heterogeneity
# its firm's global strategic posture | posture pobj of
# supplemental analyses | analyses pobj In
# effects | effects nsubjpass found
# firm tenure | tenure pobj for
# industry tenure | tenure dobj using
# tenure | tenure conj tenure
# the TMT | TMT pobj on
# the linear main effect results | results nsubj provide
# general support | support dobj provide
# Hypotheses la | la pobj for
# I | I nsubj d
# the direction | direction dobj contradict
# the relationship | relationship pobj of
# Hypothesis Ic | Ic pobj by
# functional heterogeneity | heterogeneity pobj on
# Alternatively , Hypotheses 2a - predict | predict ROOT predict
# the effects | effects nsubjpass curvilinear
# TMT characteristics | characteristics pobj of
# respect | respect pobj with
# global strategic posture | posture pobj to
# Alternatively , Hypotheses 2a - predict | predict ROOT predict
# the effects | effects nsubjpass curvilinear
# TMT characteristics | characteristics pobj of
# respect | respect pobj with
# global strategic posture | posture pobj to
# these hypotheses | hypotheses dobj test
# we | we nsubj added
# a squared term | term dobj added
# model | model pobj in
# none | none dobj added
# the squared - coef - 2 Summary | Summary pobj of
# Results | Results pobj of
# OLS Fixed - Regression Analyses | Analyses pobj of
# Global Strategic Posturea Variable | Variable pobj for
# 2 Model | Model appos Model
# 3 Model | Model appos Model
# 18 TMT educational heterogeneity | heterogeneity nsubj lb
# TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# - 07t TMT firm tenure heterogeneity | heterogeneity ROOT heterogeneity
# i | i nsubj d
# 12 Curvilinear effects | effects nsubj squared
# TMT international experience | experience nsubj squared
# educational heterogeneity | heterogeneity nsubj squared
# TMT functional heterogeneity squared 2c - 05 TMT firm tenure heterogeneity | heterogeneity nsubj squared
# 29 TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# Controls Organizational size | size appos heterogeneity
# 07t | t ROOT t
# 07t | t ROOT t
# 07t | t ROOT t
# 07t Return | Return ROOT Return
# assets | assets pobj on
# Current ratio - 06 - 06 - 07 - 07 Free cash flow | flow ROOT flow
# 10t | t appos 09o
# 09 TMT size | size ROOT size
# 11 Period | Period ROOT Period
# 09t | t ROOT t
# 08t | t ROOT t
# 05 TMT average tenure | tenure ROOT tenure
# 07t | t ROOT t
# 07t | t ROOT t
# TMT turnover | turnover ROOT turnover
# . 03 Environmental uncertainty | uncertainty ROOT uncertainty
# 1lt Adjusted R2 | R2 ROOT R2
# 33 Change | Change ROOT Change
# adjusted R2 | R2 pobj in
# 04 a n 414 207 cases | cases nsubj multiplied
# two years | years pobj by
# Standardized coefficients | coefficients nsubjpass shown
# 10 p . 05 p | p ROOT p
# the main effect results | results nsubj were
# model | model pobj in
# these studies | studies nsubj argue
# moderate levels | levels nsubj be
# team member heterogeneity | heterogeneity pobj of
# the varied networks | networks pobj because
# skills | skills conj networks
# worldviews | worldviews conj skills
# diversity | diversity nsubj provides
# excessive heterogeneity | heterogeneity nsubj lead
# interpersonal conflict and communication breakdowns | breakdowns pobj to
# a TMT's overall behavioral integration | integration pobj from
# Anthe development | development dobj suggested
# the first set | set pobj of
# hypotheses | hypotheses pobj of
# extremely low levels | levels nsubj limit
# TMT heterogeneity | heterogeneity pobj of
# teams' sociocognitive capacity | capacity dobj limit
# breadth | breadth conj capacity
# network ties | ties pobj of
# skill sets | sets conj ties
# domestic myopia | myopia pobj in
# groupthink | groupthink conj myopia
# the complexity | complexity pobj Given
# characterizing firms | firms pobj Given
# expansive global positions | positions pobj with
# hence the need | need conj firms
# both diversity | diversity pobj for
# high levels | levels conj diversity
# teamwork | teamwork pobj of
# their top management teams | teams pobj in
# Kim Mauborgne | Mauborgne appos teams
# Weick Van Orden | Orden conj Mauborgne
# this evidence | evidence nsubj suggests
# the relationship | relationship nsubjpass curvilinear
# TMT characteristics | characteristics pobj between
# global strategic posture | posture conj characteristics
# an inverted U | U dobj curvilinear
# the complexity | complexity pobj Given
# characterizing firms | firms pobj Given
# expansive global positions | positions pobj with
# hence the need | need conj firms
# both diversity | diversity pobj for
# high levels | levels conj diversity
# teamwork | teamwork pobj of
# their top management teams | teams pobj in
# Kim Mauborgne | Mauborgne appos teams
# Weick Van Orden | Orden conj Mauborgne
# this evidence | evidence nsubj suggests
# the relationship | relationship nsubjpass curvilinear
# TMT characteristics | characteristics pobj between
# global strategic posture | posture conj characteristics
# an inverted U | U dobj curvilinear
# we | we nsubj offer
# the following hypotheses | hypotheses dobj offer
# alternatives | alternatives pobj as
# the linear relationships | relationships pobj to
# a curvilinear | curvilinear attr be
# U - relationship | relationship dobj inverted
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# reason | reason attr is
# such uncertainty | uncertainty nsubj affect
# the relationship | relationship dobj affect
# TMT demographics | demographics pobj between
# global strategic posture | posture conj demographics
# the context | context pobj In
# this study | study pobj of
# it | it nsubj suggests
# the following hypotheses | hypotheses dobj suggests
# Environmental uncertainty | uncertainty nsubj moderate
# the previously proposed linear relationships | relationships dobj moderate
# a top management team's international work experience | experience pobj between
# the expansiveness | expansiveness conj experience
# its firm's global strategic posture | posture pobj of
# Analytical Approach | Approach ROOT Approach
# Variables | Variables conj Approach
# Measures Analytical | Analytical nsubj approach
# Hypotheses | Hypotheses nsubjpass tested
# two panels | panels pobj with
# ordinary least squares | squares nsubjpass used
# OLS regression analysis | analysis dobj squares
# fixed - models | models pobj with
# unobserved differences | differences pobj for
# firms | firms pobj between
# Generalized least squares | squares ROOT squares
# GLS random - regression | regression nsubjpass used
# upper echelons studies | studies pobj in
# multiple panels | panels dobj incorporating
# data e | e pobj of
# g . , Finkelstein Ham | Ham ROOT Ham
# the Hausman specification test | test nsubj suggested
# a fixed - model | model nsubj was
# a random - model | model pobj than
# Independent variables | variables ROOT variables
# Select TMT demographic characteristics | characteristics nsubj comprised
# the set | set dobj comprised
# independent variables | variables pobj of
# all the hypotheses | hypotheses dobj test
# other upper echelons studies | studies pobj Following
# we | we nsubj defined
# the top management team | team dobj defined
# the top two tiers | tiers pobj as
# an organization's management | management pobj of
# Moderator variable | variable ROOT variable
# uncertainty | uncertainty nsubj moderate
# the main effect relationships | relationships dobj moderate
# Hypotheses la | la pobj in
# We | We nsubj gauged
# environmental uncertainty | uncertainty dobj gauged
# a variation | variation dobj using
# the environmental instability measure | measure pobj of
# Dess | Dess pobj by
# Beard | Beard conj Dess
# Moderator variable | variable ROOT variable
# uncertainty | uncertainty nsubj moderate
# the main effect relationships | relationships dobj moderate
# Hypotheses la | la pobj in
# We | We nsubj gauged
# environmental uncertainty | uncertainty dobj gauged
# a variation | variation dobj using
# the environmental instability measure | measure pobj of
# Dess | Dess pobj by
# Beard | Beard conj Dess
# variable inflation factor VIF scores | scores nsubj were
# all the models | models pobj for
# acceptable parameters | parameters pobj within
# multicollinearity | multicollinearity nsubj was
# a problem | problem attr was
# Chatterjee Price | Price appos problem
# the hypotheses | hypotheses nsubjpass tested
# fixed - models and OLS regression | regression dobj using
# regression | regression nsubj results
# both main and moderated effects | effects pobj for
# Table | Table pobj in
# Model | Model nsubj includes
# only the control variables | variables dobj includes
# model | model conj includes
# the variables | variables nsubj needed
# the main effects | effects dobj test
# Hypotheses | Hypotheses nsubj laid
# predict | predict dobj laid
# select TMT characteristics | characteristics nsubjpass related
# global strategic posture | posture pobj to
# both the control model | model nsubj were
# the full models | models nsubj model
# the change | change nsubj was
# R2 | R2 pobj in
# model | model pobj in
# the coefficients | coefficients nsubj were
# international work experience | experience pobj for
# educational heterogeneity | heterogeneity conj experience
# firm tenure heterogeneity | heterogeneity conj heterogeneity
# functional heterogeneity | heterogeneity pobj for
# supplemental analyses | analyses pobj In
# effects | effects nsubjpass found
# firm tenure | tenure pobj for
# industry tenure | tenure dobj using
# tenure | tenure conj tenure
# the TMT | TMT pobj on
# the linear main effect results | results nsubj provide
# general support | support dobj provide
# Hypotheses la | la pobj for
# I | I nsubj d
# the direction | direction dobj contradict
# the relationship | relationship pobj of
# Hypothesis Ic | Ic pobj by
# functional heterogeneity | heterogeneity pobj on
# Alternatively , Hypotheses 2a - predict | predict ROOT predict
# the effects | effects nsubjpass curvilinear
# TMT characteristics | characteristics pobj of
# respect | respect pobj with
# global strategic posture | posture pobj to
# the linear main effect results | results nsubj provide
# general support | support dobj provide
# Hypotheses la | la pobj for
# I | I nsubj d
# the direction | direction dobj contradict
# the relationship | relationship pobj of
# Hypothesis Ic | Ic pobj by
# functional heterogeneity | heterogeneity pobj on
# Alternatively , Hypotheses 2a - predict | predict ROOT predict
# the effects | effects nsubjpass curvilinear
# TMT characteristics | characteristics pobj of
# respect | respect pobj with
# global strategic posture | posture pobj to
# these hypotheses | hypotheses dobj test
# we | we nsubj added
# a squared term | term dobj added
# model | model pobj in
# none | none dobj added
# the squared - coef - 2 Summary | Summary pobj of
# Results | Results pobj of
# OLS Fixed - Regression Analyses | Analyses pobj of
# Global Strategic Posturea Variable | Variable pobj for
# 2 Model | Model appos Model
# 3 Model | Model appos Model
# 18 TMT educational heterogeneity | heterogeneity nsubj lb
# TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# - 07t TMT firm tenure heterogeneity | heterogeneity ROOT heterogeneity
# i | i nsubj d
# 12 Curvilinear effects | effects nsubj squared
# TMT international experience | experience nsubj squared
# educational heterogeneity | heterogeneity nsubj squared
# TMT functional heterogeneity squared 2c - 05 TMT firm tenure heterogeneity | heterogeneity nsubj squared
# 29 TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# Controls Organizational size | size appos heterogeneity
# 07t | t ROOT t
# 07t | t ROOT t
# 07t | t ROOT t
# 07t Return | Return ROOT Return
# assets | assets pobj on
# Current ratio - 06 - 06 - 07 - 07 Free cash flow | flow ROOT flow
# 10t | t appos 09o
# 09 TMT size | size ROOT size
# 11 Period | Period ROOT Period
# 09t | t ROOT t
# 08t | t ROOT t
# 05 TMT average tenure | tenure ROOT tenure
# 07t | t ROOT t
# 07t | t ROOT t
# TMT turnover | turnover ROOT turnover
# . 03 Environmental uncertainty | uncertainty ROOT uncertainty
# 1lt Adjusted R2 | R2 ROOT R2
# 33 Change | Change ROOT Change
# adjusted R2 | R2 pobj in
# 04 a n 414 207 cases | cases nsubj multiplied
# two years | years pobj by
# Alternatively , Hypotheses 2a - predict | predict ROOT predict
# the effects | effects nsubjpass curvilinear
# TMT characteristics | characteristics pobj of
# respect | respect pobj with
# global strategic posture | posture pobj to
# these hypotheses | hypotheses dobj test
# we | we nsubj added
# a squared term | term dobj added
# model | model pobj in
# none | none dobj added
# the squared - coef - 2 Summary | Summary pobj of
# Results | Results pobj of
# OLS Fixed - Regression Analyses | Analyses pobj of
# Global Strategic Posturea Variable | Variable pobj for
# 2 Model | Model appos Model
# 3 Model | Model appos Model
# 18 TMT educational heterogeneity | heterogeneity nsubj lb
# TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# - 07t TMT firm tenure heterogeneity | heterogeneity ROOT heterogeneity
# i | i nsubj d
# 12 Curvilinear effects | effects nsubj squared
# TMT international experience | experience nsubj squared
# educational heterogeneity | heterogeneity nsubj squared
# TMT functional heterogeneity squared 2c - 05 TMT firm tenure heterogeneity | heterogeneity nsubj squared
# 29 TMT functional heterogeneity | heterogeneity ROOT heterogeneity
# Controls Organizational size | size appos heterogeneity
# 07t | t ROOT t
# 07t | t ROOT t
# 07t | t ROOT t
# 07t Return | Return ROOT Return
# assets | assets pobj on
# Current ratio - 06 - 06 - 07 - 07 Free cash flow | flow ROOT flow
# 10t | t appos 09o
# 09 TMT size | size ROOT size
# 11 Period | Period ROOT Period
# 09t | t ROOT t
# 08t | t ROOT t
# 05 TMT average tenure | tenure ROOT tenure
# 07t | t ROOT t
# 07t | t ROOT t
# TMT turnover | turnover ROOT turnover
# . 03 Environmental uncertainty | uncertainty ROOT uncertainty
# 1lt Adjusted R2 | R2 ROOT R2
# 33 Change | Change ROOT Change
# adjusted R2 | R2 pobj in
# 04 a n 414 207 cases | cases nsubj multiplied
# two years | years pobj by
# Standardized coefficients | coefficients nsubjpass shown
# 10 p . 05 p | p ROOT p
# the main effect results | results nsubj were
# model | model pobj in
# some research | research pobj to
# Wiersema | Wiersema dobj supporting
# Bantel | Bantel conj Wiersema
# the curvilinear predictions | predictions nsubj hold
# The final set | set nsubj predicts
# hypotheses | hypotheses pobj of
# the relationship | relationship nsubjpass influenced
# TMT characteristics | characteristics pobj between
# global strategic posture | posture conj characteristics
# an interaction | interaction pobj by
# uncertainty | uncertainty pobj with
# it | it nsubj was
# these hypotheses | hypotheses dobj analyze
# a regression equation | equation dobj estimating
# a multiplicative interaction term | term pobj with
# the interactions | interactions dobj decomposing
# their simple effects | effects pobj into
# The final set | set nsubj predicts
# hypotheses | hypotheses pobj of
# the relationship | relationship nsubjpass influenced
# TMT characteristics | characteristics pobj between
# global strategic posture | posture conj characteristics
# an interaction | interaction pobj by
# uncertainty | uncertainty pobj with
# it | it nsubj was
# these hypotheses | hypotheses dobj analyze
# a regression equation | equation dobj estimating
# a multiplicative interaction term | term pobj with
# the interactions | interactions dobj decomposing
# their simple effects | effects pobj into
# The tests | tests nsubjpass shown
# the uncertainty interaction hypotheses | hypotheses pobj of
# model | model pobj in
# it | it nsubj was
# these hypotheses | hypotheses dobj analyze
# a regression equation | equation dobj estimating
# a multiplicative interaction term | term pobj with
# the interactions | interactions dobj decomposing
# their simple effects | effects pobj into
# The tests | tests nsubjpass shown
# the uncertainty interaction hypotheses | hypotheses pobj of
# model | model pobj in
# The interactions | interactions nsubj were
# uncertainty | uncertainty pobj of
# tenure heterogeneity | heterogeneity pobj with
# educational heterogeneity | heterogeneity conj heterogeneity
# functional heterogeneity | heterogeneity conj heterogeneity
# the full model's increase | increase nsubj was
# R2 | R2 pobj in
# the main effects model | model pobj over
# regression coefficients | coefficients nsubj were
# the interactions | interactions pobj for
# each variable | variable nsubjpass run
# separate models | models pobj in
# the coefficients | coefficients nsubj were
# these TMT characteristics | characteristics pobj of
# low moderator levels | levels pobj at
# they | they nsubj became
# the moderators | moderators nsubj passed
# their median levels | levels dobj passed
# adjusted Bonferoni procedure | procedure conj became
# uncertainty | uncertainty nsubj moderated
# the TMT demographic variables | variables pobj of
# the positive direction | direction nsubjpass supported
# the third set | set pobj by
# hypotheses | hypotheses pobj of
# educational heterogeneity | heterogeneity pobj for
# DISCUSSION | DISCUSSION ROOT DISCUSSION
# The primary objective | objective nsubj was
# this study | study pobj of
# top management teams | teams dobj bring
# the literature | literature pobj into
# globalization | globalization pobj on
# support | support pobj In
# our expectations | expectations pobj of
# the results | results nsubj indicate
# 1 a top team's characteristics | characteristics nsubjpass related
# the degree | degree pobj to
# its firm | firm nsubj was
# such relationships | relationships nsubj were
# the level | level pobj upon
# environmental uncertainty | uncertainty pobj of
# the top team | team dobj confronting
# the direction | direction nsubj varied
# the moderated relationships | relationships pobj of
# only mixed support | support dobj providing
# These findings | findings nsubj have
# important implications | implications dobj have
# work | work pobj for
# both globalization | globalization pobj on
# upper echelons | echelons conj globalization
# contrast | contrast pobj In
# what | what dobj imply
# an upper echelons view | view nsubj imply
# functional heterogeneity | heterogeneity nsubj exhibited
# a negative linear relationship | relationship dobj exhibited
# global strategic posture | posture pobj with
# it | it nsubj is
# our first set | set pobj to
# hypotheses | hypotheses pobj of
# such a finding | finding nsubj is
# arguments | arguments pobj with
# demographic heterogeneity | heterogeneity nsubj detract
# team cohesiveness | cohesiveness pobj from
# disagreement | disagreement dobj promote
# an organization | organization pobj about
# its goals | goals conj organization
# Ancona Caldwell | Caldwell appos goals
# O'Reilly et al | al appos finding
# Conflict | Conflict nsubj lead
# top team members | members pobj among
# turn | turn pobj in
# a firm | firm dobj lead
# its strategic actions | actions pobj in
# it | it nsubj difficult
# the commitment | commitment dobj gain
# its domestic position | position pobj beyond
# Ohmae | Ohmae appos position
# this result | result nsubj suggests
# a firm's ability | ability nsubjpass stifled
# an expansive global strategic posture | posture dobj realize
# its top team | team nsubj has
# executives | executives dobj has
# dramatically different functional experiences | experiences pobj with
# Conclusions | Conclusions ROOT Conclusions
# Implications | Implications conj Conclusions
# Drawn | Drawn conj Conclusions
# the Interactions | Interactions pobj from
# We | We nsubj argued
# high uncertainty | uncertainty nsubj moderate
# the relationship | relationship dobj moderate
# TMT demographics | demographics pobj between
# global strategic posture | posture conj demographics
# This view | view nsubj is
# the broader literature | literature pobj with
# such relationships | relationships nsubj vary
# the organizational and environmental contexts | contexts pobj to
# a top team | team dobj confronting
# Blue | Blue dobj see
# colleagues | colleagues conj Blue
# a review | review pobj for
# Finkelstein | Finkelstein dobj see
# Hambrick | Hambrick conj Finkelstein
# Miller | Miller appos Finkelstein
# Murray | Murray conj Miller
# These results | results nsubj contradict
# the third set | set dobj contradict
# predictions | predictions pobj of
# these negative simple effects | effects nsubj were
# our upper echelons predictions | predictions pobj of
# the first set | set attr were
# hypotheses | hypotheses pobj of
# qualified support | support dobj lend
# the level | level pobj on
# uncertainty | uncertainty pobj of
# the arguments | arguments pobj to
# researchers | researchers pobj of
# who | who nsubj suggest
# the behavioral implications | implications nsubj lead
# top team heterogeneity | heterogeneity pobj of
# conflict | conflict pobj to
# a team's ability | ability dobj hinder
# complexity O'Reilly et al | al dobj manage
# some past research | research nsubj attempted
# these divergent positions | positions dobj bridge
# an inverted - or curvilinear relationship | relationship dobj suggesting
# demographic heterogeneity | heterogeneity pobj between
# organizational outcomes Jackson | Jackson conj heterogeneity
# Wiersema Bantel | Bantel appos research
# some past research | research nsubj attempted
# these divergent positions | positions dobj bridge
# an inverted - or curvilinear relationship | relationship dobj suggesting
# demographic heterogeneity | heterogeneity pobj between
# organizational outcomes Jackson | Jackson conj heterogeneity
# Wiersema Bantel | Bantel appos research
# we | we nsubj found
# no support | support dobj found
# the curvilinear predictions | predictions pobj for
# hypotheses | hypotheses pobj of
# our results | results nsubj suggest
# a refinement | refinement dobj suggest
# arguments | arguments nsubj hold
# the nonmonotonic effects | effects pobj about
# heterogeneity | heterogeneity pobj of
# some demographic characteristics | characteristics pobj for
# one | one nsubj take
# account | account pobj into
# the level | level dobj take
# uncertainty | uncertainty pobj of
# a top team | team dobj facing

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
# Out:
# Apple apple PROPN NNP nsubj Xxxxx True False
# is be VERB VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. u.k. PROPN NNP compound X.X. False False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
doc = nlp(phrase)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Nevertheless nevertheless ADV RB advmod Xxxxx True False
# , , PUNCT , punct , False False
# we -PRON- PRON PRP nsubj xx True True
# found find VERB VBD ROOT xxxx True False
# no no DET DT det xx True True
# support support NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# curvilinear curvilinear NOUN NN compound xxxx True False
# predictions prediction NOUN NNS pobj xxxx True False
# the the DET DT det xxx True True
# second second ADJ JJ amod xxxx True False
# set set NOUN NN oprd xxx True False
# of of ADP IN prep xx True True
# hypotheses hypothesis NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# our -PRON- ADJ PRP$ poss xxx True True
# results result NOUN NNS nsubj xxxx True False
# suggest suggest VERB VBP conj xxxx True False
# instead instead ADV RB advmod xxxx True False
# a a DET DT det x True True
# refinement refinement NOUN NN dobj xxxx True False
# to to ADP IN prep xx True True
# such such ADJ JJ amod xxxx True True
# theorizing theorize VERB VBG pobj xxxx True False
# . . PUNCT . punct . False False

# %%
for chunk in doc.noun_chunks:
    print(chunk.text, '|', chunk.root.text, chunk.root.dep_,
          chunk.root.head.text)
# Out:
# we | we nsubj found
# no support | support dobj found
# the curvilinear predictions | predictions pobj for
# hypotheses | hypotheses pobj of
# our results | results nsubj suggest
# a refinement | refinement dobj suggest
