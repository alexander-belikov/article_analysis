# %%
import camelot

# %%
# tables = camelot.read_pdf('/Users/belikov/data/jstor/pdfs/carpenter2001.pdf')
tables = camelot.read_pdf('/Users/belikov/data/jstor/pdfs/t1.pdf', flavor='stream')
tables2 = camelot.read_pdf('/Users/belikov/data/jstor/pdfs/t2.pdf', flavor='stream')

# %%
tables, tables2
# Out:
# (<TableList n=2>, <TableList n=3>)

# %%
t = tables[1]
t.parsing_report
t.df.head(10)
# Out:
#                                                   0         1     2   \
# 0  tively  identical results. Additionally, firm ...
# 1
# 2
# 3                                                     Variable  Mean
# 4                                                         size  2.42
# 5                                  1. Organizational
# 6                               2. Return on  assets            0.10
# 7                                   3. Current ratio            0.90
# 8                                 4. Free cash  flow            9.57
# 9                                 5. Diversification     level  0.26
#
#                                          3     4     5        6    7   \
# 0
# 1                                                        TABLE 1
# 2  Descriptive Statistics and Correlationsa
# 3                                      s.d.     1     2        3    4
# 4                                      1.37
# 5
# 6                                      0.09   .01
# ...

# %%
t = tables2[1]
t.parsing_report
t.df
# Out:
#                                                     0  \
# 0                                             TABLE 2
# 1   Summary  of Results  of OLS Fixed-Effects  Reg...
# 2                                 Model  1 \nVariable
# 3                                          Hypothesis
# 4                                       Main  effects
# 5                              la \nTMT international
# 6                                          experience
# 7                                                  lb
# 8                      TMT educational  heterogeneity
# 9                                                  lc
# 10                      TMT functional  heterogeneity
# 11                                                 id
# 12                     TMT firm tenure  heterogeneity
# 13                               Curvilinear  effects
# 14                             2a \nTMT international
# 15                               squared \nexperience
# ...

# %%
t = tables2[2]
t.parsing_report
t.df
# Out:
#                                  0           1   2      3      4      5      6
# 0                TMT international              3a                         .03
# 1                                   experience
# 2                                               3b                        .29*
# 3   TMT educational  heterogeneity
# 4                                               3c                       -.45*
# 5    TMT functional  heterogeneity
# 6                                               3d                       -.19*
# 7   TMT firm tenure  heterogeneity
# 8                         Controls
# 9                             size                   .07t   .07t   .07t   .07t
# 10                  Organizational
# 11               Return on  assets                    .06    .05    .05    .06
# 12                   Current ratio                   -.06   -.06   -.07   -.07
# 13                 Free cash  flow                    .02    .03    .03    .03
# ...

# %%
tables = camelot.read_pdf('/Users/belikov/data/jstor/pdfs/carpenter2001.pdf', pages='all', flavor='stream')

# %%
tables_true = [t for t in tables if any([w for w in t.df.values.flatten() if 'table' in w.lower()])]

# %%
len(tables_true)
# Out:
# 8

# %%
for t in tables_true:
    print(t.df.head())
# Out:
#                                                    0
# 0  Top Management Teams, Global Strategic Posture...
# 1  Author(s): Mason A. Carpenter and James W. Fre...
# 2  Source: The Academy of Management Journal, Vol...
# 3                Published by: Academy of Management
# 4  Stable URL: http://www.jstor.org/stable/3069368 .
#                                                    0  \
# 0                                        a \nbetween
# 1              verted  U-shaped \nrelationship \ntop
# 2                team's  firm  tenure  heterogeneity
# 3                                         management
# 4  and  the  expansiveness \nof its firm's  globa...
#
#                                          1
# 0
# 1
# 2  are  con- \nTherefore,  upper  echelons
# 3                              predictions
# 4                                    teams
#                                                    0  \
# 0  there is reason to expect that such uncertaint...
# ...

# %%
[t.df.shape for t in tables_true]
# Out:
# (19, 18)

# %%
tables = camelot.read_pdf('/Users/belikov/data/jstor/pdfs/carpenter2001.pdf', pages='8-9', flavor='stream')

# %%
len(tables)
# Out:
# 5

# %%
tables_true = [t for t in tables if any([w for w in t.df.values.flatten() if 'table' in w.lower()])]

# %%
[t.df.shape for t in tables_true]
# Out:
# [(19, 18), (35, 2)]

# %%
tables[-2].df
# Out:
#                                                     0  \
# 0   Summary  of  Results  of  OLS Fixed-Effects  R...
# 1                                 Model  1 \nVariable
# 2                                          Hypothesis
# 3                                       Main  effects
# 4                              la \nTMT international
# 5                                          experience
# 6                                                  lb
# 7                      TMT educational  heterogeneity
# 8                                                  lc
# 9                       TMT functional  heterogeneity
# 10                                                 id
# 11                     TMT firm tenure  heterogeneity
# 12                               Curvilinear  effects
# 13                             2a \nTMT international
# 14                               squared \nexperience
# 15                                                 2b
# ...
